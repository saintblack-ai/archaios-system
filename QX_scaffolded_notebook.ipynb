# %% [markdown]
# # QX Research and Topics
#
# A comprehensive exploration of Quantum Computing, Robotics, and Nuclear Energy, including code samples, chapter outlines, and key research summaries.

# %% [markdown]
# ## Quantum Computing Code Sample
# Create and measure a Bell state using Qiskit.

# %%
from qiskit import QuantumCircuit, Aer, execute
from qiskit.visualization import plot_histogram

# Create and run a Bell-state circuit
qc = QuantumCircuit(2, 2)
qc.h(0)
qc.cx(0, 1)
qc.measure([0,1], [0,1])

backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend, shots=1024)
counts = job.result().get_counts()

print("Measurement counts:", counts)
plot_histogram(counts)

# %% [markdown]
# ## Robotics Code Sample
# ROS 2 publisher that sends greeting messages every second.

# %%
import rclpy
from rclpy.node import Node
from std_msgs.msg import String

class HelloPublisher(Node):
    def __init__(self):
        super().__init__('hello_publisher')
        self.pub = self.create_publisher(String, 'greetings', 10)
        self.timer = self.create_timer(1.0, self.timer_callback)
        self.count = 0

    def timer_callback(self):
        msg = String()
        msg.data = f'Hello, world! {self.count}'
        self.pub.publish(msg)
        self.get_logger().info(f'Published: "{msg.data}"')
        self.count += 1

def main(args=None):
    rclpy.init(args=args)
    node = HelloPublisher()
    rclpy.spin(node)
    node.destroy_node()
    rclpy.shutdown()

if __name__ == '__main__':
    main()

# %% [markdown]
# ## Nuclear Energy Code Sample
# Solve a 1D neutron diffusion equation using finite differences.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1D neutron diffusion
L, N = 100.0, 101
dx = L/(N-1)
D, Sigma_a, nuSigma_f = 1.2, 0.01, 0.02

# Build matrix and source
A = np.zeros((N, N))
S = np.zeros(N)
for i in range(1, N-1):
    A[i,i-1] = D/dx**2
    A[i,i]   = -2*D/dx**2 - Sigma_a
    A[i,i+1] = D/dx**2
    S[i]    = -nuSigma_f

# Boundary conditions
A[0,0] = A[-1,-1] = 1.0
phi = np.linalg.solve(A, -S)

# Plot
plt.plot(np.linspace(0, L, N), phi)
plt.xlabel('Position (cm)')
plt.ylabel('Neutron Flux')
plt.title('1D Neutron Diffusion')
plt.show()
